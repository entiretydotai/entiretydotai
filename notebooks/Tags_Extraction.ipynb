# %%
import sys
sys.path.append("..")

# %%
import numpy as np
import pandas as pd
from src import FlairDataset,FlairTagging
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
path = "../data/external/real_fake_disaster/"

# %%
dataset = FlairDataset.csv_classification(
    data_folder=path, filename='data', column_mapping=['text', 'label'])
# Out:
# 2020-04-07 01:29:31,026 entiretydotai DEBUG Found directory : /home/uv/Documents/meetup(in_progress)/entiretydotai/data/external/real_fake_disaster
# 2020-04-07 01:29:31,029 entiretydotai DEBUG Number of files found 1
# 2020-04-07 01:29:31,031 entiretydotai DEBUG Found 1 file : data.csv
# 2020-04-07 01:29:31,033 entiretydotai DEBUG Setting train_val_test_split_flag to True
# 2020-04-07 01:29:31,037 entiretydotai DEBUG [sel_column_label] : Ran with args: (PosixPath('/home/uv/Documents/meetup(in_progress)/entiretydotai/data/external/real_fake_disaster/data.csv'), ['text', 'label'], ['text', 'label']), and kwargs: {}
# 2020-04-07 01:29:31,074 entiretydotai DEBUG [sel_column_label] ran in: 0.03502154350280762 sec
# 2020-04-07 01:29:31,075 entiretydotai DEBUG [column_name_map] {3: 'text', 4: 'label'}
# 2020-04-07 01:29:31,094 entiretydotai DEBUG NUmber of rows in the dataset: 7613
# 2020-04-07 01:29:31,095 entiretydotai DEBUG NUmber of rows in train dataset: 6165
# ...

# %%
dataset.train_data.reset_index(drop=True).loc[:10,:]
# Out:
#        id       keyword                     location  \
# 0    9831        trauma                          NaN
# 1    9672       tornado                          NaN
# 2   10421     whirlwind                     Internet
# 3    1316        bloody  peekskill. new york, 10566
# 4    8483      screamed            'SAN ANTONIOOOOO'
# 5    6282     hijacking                          NaN
# 6    7733     panicking                          VCU
# 7    4917      exploded                          NaN
# 8    2739       crushed                 Pennsylvania
# 9    4889       explode                United States
# 10   4306  dust%20storm                          NaN
#
#                                                  text  label
# 0   @AshGhebranious civil rights continued in the ...      0
# 1   Dakota Skye gets horny with some porn then get...      0
# 2   Richard returns after whirlwind few days http:...      1
# 3   Bloody Mary in the sink. Beet juice http://t.c...      0
# ...

# %%
tagger = FlairTagging(dataset)

# %%
df = tagger.add_tags(model = 'ner-fast',tag_type = 'ner', extract_tags=True,return_score=True)#
# Out:
# 2020-04-07 01:29:31,418 entiretydotai DEBUG Shape of the dataframe:(11, 5)
# 2020-04-07 01:29:31,422 loading file /home/uv/.flair/models/en-ner-fast-conll03-v0.4.pt
# 2020-04-07 01:29:32,688 entiretydotai DEBUG MODEL: [ner-fast] is loaded ...
# 2020-04-07 01:29:34,718 entiretydotai DEBUG [flair_tags] ran in: 3.2965176105499268 sec

# %%
df = df.rename(columns={6:'tags',5:'text',7:'score'})

# %%
# Length of text and tag columns are same
df.text.str.len(),df.tags.str.len()
# Out:
# (0     20
#  1     18
#  2      8
#  3      8
#  4     24
#  5     16
#  6     16
#  7     19
#  8      9
#  9     13
#  10    12
#  Name: text, dtype: int64, 0     20
#  1     18
#  2      8
#  3      8
#  4     24
#  5     16
#  6     16
#  7     19
#  8      9
#  9     13
#  10    12
#  Name: tags, dtype: int64)

# %%
# You can join the text,tags as a string 
df.text.str.join(" ")
# Out:
# 0     @AshGhebranious civil rights continued in the ...
# 1     Dakota Skye gets horny with some porn then get...
# 2     Richard returns after whirlwind few days http:...
# 3     Bloody Mary in the sink. Beet juice http://t.c...
# 4     @Real_Liam_Payne I SCREAMED AT THE TOP OF MY L...
# 5     Mom is hijacking my account to earn MCR STATUS...
# 6     Just realized that maybe it not normal to sit ...
# 7     Im Dead!!! My two Loves in 1 photo! My Heart e...
# 8     Nick Williams just hit another bomb. Just crus...
# 9     Philadelphia Eagles‰Ûª Jordan Matthews Is Goin...
# 10    Kids Disappear in Dust Storm in Atmospheric Au...
# Name: text, dtype: object

# %%
df = tagger.add_tags_as_string(model = 'ner-fast',tag_type = 'ner',clean_tags = False)
# Out:
# 2020-04-07 01:29:35,058 entiretydotai DEBUG S   hape of the dataframe:(11, 5)
# 2020-04-07 01:29:35,062 loading file /home/uv/.flair/models/en-ner-fast-conll03-v0.4.pt
# 2020-04-07 01:29:36,107 entiretydotai DEBUG MODEL: [ner-fast] is loaded ...
# 2020-04-07 01:29:37,846 entiretydotai DEBUG [flair_tags_as_string] ran in: 2.7849771976470947 sec

# %%
df
# Out:
#         0             1                            2  \
# 0    9831        trauma                          NaN
# 1    9672       tornado                          NaN
# 2   10421     whirlwind                     Internet
# 3    1316        bloody  peekskill. new york, 10566
# 4    8483      screamed            'SAN ANTONIOOOOO'
# 5    6282     hijacking                          NaN
# 6    7733     panicking                          VCU
# 7    4917      exploded                          NaN
# 8    2739       crushed                 Pennsylvania
# 9    4889       explode                United States
# 10   4306  dust%20storm                          NaN
#
#                                                     3  4  \
# 0   @AshGhebranious civil rights continued in the ...  0
# 1   Dakota Skye gets horny with some porn then get...  0
# 2   Richard returns after whirlwind few days http:...  1
# 3   Bloody Mary in the sink. Beet juice http://t.c...  0
# ...

# %%
FlairTagging.__repr__(dataset)
# Out:
# "Text: Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all Tokens: ['Our', 'Deeds', 'are', 'the', 'Reason', 'of', 'this', '#earthquake', 'May', 'ALLAH', 'Forgive', 'us', 'all']"
