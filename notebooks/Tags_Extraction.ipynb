# %%
import sys
sys.path.append("..")

# %%
import numpy as np
import pandas as pd
from src import FlairDataset,FlairTagging
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
path = "../data/external/real_fake_disaster/"

# %%
dataset = FlairDataset.csv_classification(
    data_folder=path, filename='data', column_mapping=['text', 'label'])
# Out:
# 2020-04-06 01:35:33,399 entiretydotai DEBUG Found directory : /home/uv/Documents/meetup(in_progress)/entiretydotai/data/external/real_fake_disaster
# 2020-04-06 01:35:33,405 entiretydotai DEBUG Number of files found 1
# 2020-04-06 01:35:33,410 entiretydotai DEBUG Found 1 file : data.csv
# 2020-04-06 01:35:33,413 entiretydotai DEBUG Setting train_val_test_split_flag to True
# 2020-04-06 01:35:33,416 entiretydotai DEBUG [sel_column_label] : Ran with args: (PosixPath('/home/uv/Documents/meetup(in_progress)/entiretydotai/data/external/real_fake_disaster/data.csv'), ['text', 'label'], ['text', 'label']), and kwargs: {}
# 2020-04-06 01:35:33,455 entiretydotai DEBUG [sel_column_label] ran in: 0.0375370979309082 sec
# 2020-04-06 01:35:33,456 entiretydotai DEBUG [column_name_map] {3: 'text', 4: 'label'}
# 2020-04-06 01:35:33,466 entiretydotai DEBUG NUmber of rows in the dataset: 7613
# 2020-04-06 01:35:33,467 entiretydotai DEBUG NUmber of rows in train dataset: 6165
# ...

# %%
dataset.train_data.reset_index(drop=True).loc[:10,:]
# Out:
#        id       keyword                     location  \
# 0    9831        trauma                          NaN
# 1    9672       tornado                          NaN
# 2   10421     whirlwind                     Internet
# 3    1316        bloody  peekskill. new york, 10566
# 4    8483      screamed            'SAN ANTONIOOOOO'
# 5    6282     hijacking                          NaN
# 6    7733     panicking                          VCU
# 7    4917      exploded                          NaN
# 8    2739       crushed                 Pennsylvania
# 9    4889       explode                United States
# 10   4306  dust%20storm                          NaN
#
#                                                  text  label
# 0   @AshGhebranious civil rights continued in the ...      0
# 1   Dakota Skye gets horny with some porn then get...      0
# 2   Richard returns after whirlwind few days http:...      1
# 3   Bloody Mary in the sink. Beet juice http://t.c...      0
# ...

# %%
tagger = FlairTagging(dataset)

# %%
df = tagger.add_ner_tags(extract_tags=True,return_score=True)
# Out:
# 2020-04-06 01:35:33,767 entiretydotai DEBUG Shape of the dataframe:(11, 5)
# 2020-04-06 01:35:33,772 loading file /home/uv/.flair/models/en-ner-fast-conll03-v0.4.pt
# 2020-04-06 01:35:35,055 entiretydotai DEBUG ner-fast is loaded ...
# 2020-04-06 01:35:37,030 entiretydotai DEBUG [flair_ner_tags] ran in: 3.2589261531829834 sec

# %%
df
# Out:
#         0             1                            2  \
# 0    9831        trauma                          NaN
# 1    9672       tornado                          NaN
# 2   10421     whirlwind                     Internet
# 3    1316        bloody  peekskill. new york, 10566
# 4    8483      screamed            'SAN ANTONIOOOOO'
# 5    6282     hijacking                          NaN
# 6    7733     panicking                          VCU
# 7    4917      exploded                          NaN
# 8    2739       crushed                 Pennsylvania
# 9    4889       explode                United States
# 10   4306  dust%20storm                          NaN
#
#                                                     3  4  \
# 0   @AshGhebranious civil rights continued in the ...  0
# 1   Dakota Skye gets horny with some porn then get...  0
# 2   Richard returns after whirlwind few days http:...  1
# 3   Bloody Mary in the sink. Beet juice http://t.c...  0
# ...

# %%
FlairTagging.__repr__(dataset)
# Out:
# "Text: Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all Tokens: ['Our', 'Deeds', 'are', 'the', 'Reason', 'of', 'this', '#earthquake', 'May', 'ALLAH', 'Forgive', 'us', 'all']"
